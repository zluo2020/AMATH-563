# %%
import numpy as np
import scipy.integrate
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pylab as plt
# %matplotlib inline

# %%
def lorenz(t, x, b, sig, rho):
    
    return [sig * (x[1] - x[0]),  rho * x[0] - x[0]*x[2] - x[1], x[0]*x[1] - b*x[2]]

# %%
# Simulate Lorenz system
dt = 0.01 
T = 8  
t = np.arange(0, T, dt)
b = 8/3
sig = 10

# %%
def get_trajectories(rho=10):
    
    x0 = 30*(np.random.uniform(0, 1, 3)-0.5)
    y = scipy.integrate.odeint(func = lambda t,x: lorenz(t, x, b, sig, rho), y0=x0, t=t, rtol=1e-10, atol=1e-11, tfirst=True)
        
    inputs = y[:-1,:]
    outputs = y[1:,:]
    
    for i in range(100):
        
        x0 = 30*(np.random.uniform(0, 1, 3)-0.5)
        y = scipy.integrate.odeint(func = lambda t,x: lorenz(t, x, b, sig, rho), y0=x0, t=t, rtol=1e-10, atol=1e-11, tfirst=True)
        
        inputs = np.vstack((inputs, y[:-1, :]))
        outputs = np.vstack((outputs, y[1:, :]))

    
    return inputs, outputs

# %%
inputs_10, outputs_10 = get_trajectories(10)
inputs_28, outputs_28 = get_trajectories(28)
inputs_40, outputs_40 = get_trajectories(40)

# %%
inputs = np.vstack((inputs_10, inputs_28, inputs_40))

# %%
outputs = np.vstack((outputs_10, outputs_28, outputs_40))

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(3, activation='linear'))
model.compile(loss='mse', optimizer='adam', validation_split=0.2)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From c:\users\jin liu\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.fit(inputs, outputs, epochs=100)
# Out:
# WARNING:tensorflow:From c:\users\jin liu\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 242097/242097 [==============================] - 5s 23us/step - loss: 0.4022
# Epoch 2/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0336
# Epoch 3/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0241
# Epoch 4/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0202
# Epoch 5/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0181
# Epoch 6/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0168
# Epoch 7/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0157
# Epoch 8/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0153
# Epoch 9/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0143
# Epoch 10/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0144
# Epoch 11/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0136
# Epoch 12/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0130
# Epoch 13/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0129
# Epoch 14/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0127
# Epoch 15/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0127
# Epoch 16/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0124
# Epoch 17/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0122
# Epoch 18/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0119
# Epoch 19/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0114
# Epoch 20/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0113
# Epoch 21/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0114
# Epoch 22/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0111
# Epoch 23/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0109
# Epoch 24/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0107
# Epoch 25/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0108
# Epoch 26/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0105
# Epoch 27/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0105
# Epoch 28/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0101
# Epoch 29/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0103
# Epoch 30/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0102
# Epoch 31/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0100
# Epoch 32/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0101
# Epoch 33/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0099
# Epoch 34/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0098
# Epoch 35/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0098
# Epoch 36/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0098
# Epoch 37/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0097
# Epoch 38/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0095
# Epoch 39/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0095
# Epoch 40/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0095
# Epoch 41/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0095
# Epoch 42/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0093
# Epoch 43/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0092
# Epoch 44/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0093
# Epoch 45/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0094
# Epoch 46/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0092
# Epoch 47/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0091
# Epoch 48/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0090
# Epoch 49/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0092
# Epoch 50/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0091
# Epoch 51/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0091
# Epoch 52/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0090
# Epoch 53/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0089
# Epoch 54/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0088
# Epoch 55/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0089
# Epoch 56/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0089
# Epoch 57/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0088
# Epoch 58/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0089
# Epoch 59/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0086
# Epoch 60/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0087
# Epoch 61/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0088
# Epoch 62/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0084
# Epoch 63/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 64/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0086
# Epoch 65/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0086
# Epoch 66/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 67/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0086
# Epoch 68/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 69/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 70/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 71/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 72/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0083
# Epoch 73/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0084
# Epoch 74/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0083
# Epoch 75/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0085
# Epoch 76/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0084
# Epoch 77/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0083
# Epoch 78/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0084
# Epoch 79/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0083
# Epoch 80/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0084
# Epoch 81/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0082
# Epoch 82/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0081
# Epoch 83/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0082
# Epoch 84/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0082
# Epoch 85/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0080
# Epoch 86/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 87/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0082
# Epoch 88/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 89/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 90/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0080
# Epoch 91/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0080
# Epoch 92/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0081
# Epoch 93/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 94/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 95/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0080
# Epoch 96/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0080
# Epoch 97/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0081
# Epoch 98/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0079
# Epoch 99/100
# 242097/242097 [==============================] - 5s 21us/step - loss: 0.0079
# Epoch 100/100
# 242097/242097 [==============================] - 5s 22us/step - loss: 0.0081

# %%
def test(rho, model):   

    x0_test = 30*(np.random.uniform(0, 1, 3)-0.5)

    y_test = scipy.integrate.odeint(func = lambda t,x: lorenz(t, x, b, sig, rho), y0=x0_test, t=t, rtol=1e-10, atol=1e-11, tfirst=True)

    y_pred = np.zeros(y_test.shape)
    y_pred[0, :] = x0_test
    
    for i in range(1, y_pred.shape[0]):
        y_pred[i,:] = model.predict(np.expand_dims(y_pred[i-1, :], axis=1).T)
        
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot3D(y_test[:,0], y_test[:,1], y_test[:,2])
    ax.set_title('Original')
    ax.plot3D(y_pred[:,0], y_pred[:,1], y_pred[:,2])
    ax.set_title('Predicted')
    plt.title('NN rho = {}'.format(rho))
    
    
    plt.figure()
    plt.plot(y_test[:,0])
    plt.plot(y_pred[:,0])
    plt.legend(['ODE45', 'NN'])
    plt.xlabel('t')
    plt.ylabel('x(t)')
    
    plt.figure()
    plt.plot(y_test[:,1])
    plt.plot(y_pred[:,1])
    plt.legend(['ODE45', 'NN'])
    plt.xlabel('t')
    plt.ylabel('y(t)')
    
    plt.figure()
    plt.plot(y_test[:,2])
    plt.plot(y_pred[:,2])
    plt.legend(['ODE45', 'NN'])
    plt.xlabel('t')
    plt.ylabel('z(t)')

# %% [raw]
# test(35, model)
